# %% [markdown]
# <a href="https://colab.research.google.com/github/yesung05/25ML/blob/main/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9Dw3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

lifesat = pd.read_csv("taxi_fare_data_v2.csv")
X = lifesat[["distance"]].values
y = lifesat[["price"]].values

lifesat.plot(kind='scatter', grid=True, x="distance", y= "price")
plt.axis([0,50,0,150000])
plt.show()

model = LinearRegression()
model.fit(X,y)

X_new = [[5.2]]

print(model.predict(X_new))
# Out:
# [[16035.56477403]]
